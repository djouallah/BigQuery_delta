# %%
# !pip install -q google-cloud-bigquery
# !pip install -q db-dtypes
# Out:
# StatementMeta(, 81a65802-2625-403b-8755-666cc614deef, 3, Finished, Available)

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] ='/lakehouse/default/Files/test-187010-d4dea8a562f3.json'
# Out:
# StatementMeta(, 81a65802-2625-403b-8755-666cc614deef, 4, Finished, Available)

# %%
QUERY = ('''
    SELECT UNIT,RRP  FROM `test-187010.ReportingDataset.UNITARCHIVE` where day ='2024-01-02'
    ''')
# Out:
# StatementMeta(, 81a65802-2625-403b-8755-666cc614deef, 5, Finished, Available)

# %%
from google.cloud import bigquery
client = bigquery.Client(project='test-187010')
df = client.query(QUERY).to_dataframe()
# Out:
# StatementMeta(, 81a65802-2625-403b-8755-666cc614deef, 6, Finished, Available)

# %%
display(df)
# Out:
# StatementMeta(, 81a65802-2625-403b-8755-666cc614deef, 7, Finished, Available)
# SynapseWidget(Synapse.DataFrame, eb8a42c6-2bff-4c90-a2b3-0680f5b6f400)

# %%
df_spark = spark.createDataFrame(df)
df_spark.write.format("delta").mode("overwrite").saveAsTable("dailyscada")
# Out:
# StatementMeta(, 81a65802-2625-403b-8755-666cc614deef, 8, Finished, Available)
